# %% [markdown]
# <a href="https://colab.research.google.com/github/ManjithYedida/FMML-COURSE-ASSIGNMENT/blob/main/Module_8_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-04 06:31:05--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   208MB/s    in 0.3s
#
# 2023-05-04 06:31:06 (208 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12214  1710.06910v2  The past decade has witnessed a successful app...  stat
# 15989  1608.00508v2  Phonemic segmentation of speech is a critical ...    cs
# 22791  1706.08984v1  Learning by children and animals occurs effort...  stat
# 6053   1606.05798v1  As a contribution to interpretable machine lea...  stat
# 30436  1712.01970v1  A fuzzy system was created in MATLAB to identi...    cs
# ...             ...                                                ...   ...
# 6241   1610.02757v1  Our team won the second prize of the Safe Agin...  stat
# 22491  1609.08752v1  To date, the instability of prognostic predict...  stat
# 11278  1507.02216v2  Blind Source Separation is a widely used techn...  stat
# 2551   1603.04118v2  In this paper we model the problem of learning...  stat
# 10098  1705.06366v2  Reinforcement learning is a powerful technique...    cs
#
#                                                    title  year  \
# 12214  Characterization of Gradient Dominance and Reg...  2017
# 15989  Blind phoneme segmentation with temporal predi...  2016
# 22791  Unsupervised Learning via Total Correlation Ex...  2017
# 6053   Interpretable Two-level Boolean Rule Learning ...  2016
# 30436  What's in my closet?: Image classification usi...  2017
# ...                                                  ...   ...
# 6241   Dataiku's Solution to SPHERE's Activity Recogn...  2016
# 22491  Stabilizing Linear Prediction Models using Aut...  2016
# 11278              Robust Sparse Blind Source Separation  2015
# 2551   Active Algorithms For Preference Learning Prob...  2016
# 10098  Automatic Goal Generation for Reinforcement Le...  2017
#
#                                                 keywords
# 12214  [witnessed, successful, application, challengi...
# 15989  [segmentation, recognition, unsupervised, algo...
# 22791  [effortlessly, supervision, successes, automat...
# 6053   [contribution, interpretable, optimization, fr...
# 30436  [initialized, determine, characteristic, recog...
# ...                                                  ...
# 6241   [challenge, organized, conjunction, competitio...
# 22491  [instability, prognostic, predictors, dimensio...
# 11278  [separation, technique, multichannel, applicat...
# 2551   [preferences, population, algorithm, adaptivel...
# 10098  [reinforcement, technique, reinforcement, achi...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12214    [witnessed, successful, application, challengi...
# 15989    [segmentation, recognition, unsupervised, algo...
# 22791    [effortlessly, supervision, successes, automat...
# 6053     [contribution, interpretable, optimization, fr...
# 30436    [initialized, determine, characteristic, recog...
#                                ...
# 9086     [computational, framework, identification, cor...
# 6715     [processes, asynchronous, sequential, mathemat...
# 2749     [generalization, reinforcement, especially, in...
# 22312    [compressed, measurements, minimization, estim...
# 1660     [knowledge, answering, structured, relational,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8870 words.
# Out of those 4607 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8cd0249c-3ddb-4f47-b059-e60d9c372954" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8cd0249c-3ddb-4f47-b059-e60d9c372954")) {                    Plotly.newPlot(                        "8cd0249c-3ddb-4f47-b059-e60d9c372954",                        [{"x":["conditions","neighborhood","optimization","application","intelligence","parameter","directions","successful","condition","artificial","understanding","characterization","regularity","witnessed","theoretical","functions","quadratic","specifically","properties","landscape","nonlinear","desirable","dominance","establish","understood","minimizers","challenging","improvements","analyzing","prediction","segmentation","boundaries","recognition","recurrent","algorithm","hypothesize","unsupervised","environment","principle","correlation","explanation","ambiguous","multivariate","automating","characterized","suggested","effortlessly","representations","translated","supervised","information","dependence","including","successes","supervision","redundancy","theoretic","tradeoffs","programming","experiments","coordinate","conjunctive","disjunctive","algorithms","principled","minimization","contribution","objective","classification","characterize","alternating","relaxation","objectives","procedures","framework","interpretable","efficient","interpretability","inference","techniques","discussed","processing","containing","characteristic","recognize","dimensional","initialized","identification","determine","uncertainty","vagueness","alternatively","indicator","ambiguity","probability","frameworks","engineering","conceptual","adaptable","introduced","discusses","potential","distinguished","possibility","knowledge","observable","environments","acquisition","exploration","sensorimotor","extracting","emphasize","observation","integrates","partially","representation","autonomously","regularities","propagation","fortunately","experimental","bipartite","granularity","computationally","demonstrates","resulting","construct","exploring","facilitate","convolutional","collected","optimized","structure","applications","difference","restaurants","benchmark","restaurant","relationships","available","naturally","constrained","resolution","frequency","traditional","synthesis","conflicts","integrate","reviewing","assignment","separately","traditionally","preferences","assigning","formulation","predicting","integrated","management","preference","distribution","submissions","constraints","recommender","conference","assignments","reviewers","expertise","affinities","evaluated","demonstrate","practical","notwithstanding","approximation","underlying","estimating","presented","potentially","solutions","scenarios","variational","procedure","marginalization","empirical","corruptions","generative","relaxations","correctly","approaches","applicable","attention","guarantee","frequently","component","generally","minimizing","completely","intractable","consequently","methodology","surrogate"],"y":[131,28,337,240,78,107,45,86,52,117,153,37,7,7,167,209,38,167,217,5,45,34,1,51,25,4,278,98,62,221,209,32,401,134,761,8,145,116,63,89,21,16,16,8,29,26,1,220,13,199,671,25,249,8,51,14,50,5,120,595,21,5,6,575,24,69,59,145,526,43,25,20,19,41,541,35,410,16,230,382,65,287,57,31,45,199,9,109,66,80,2,9,17,26,180,27,49,17,6,127,32,162,11,34,345,27,91,36,57,4,65,9,64,31,50,341,8,6,74,4,397,10,12,83,60,156,87,44,49,349,77,51,342,450,69,2,200,3,59,314,65,71,115,54,193,39,8,45,3,27,29,19,34,9,85,83,51,43,22,219,4,150,20,12,13,2,11,1,150,537,142,1,107,134,65,201,42,143,107,65,110,1,143,2,128,11,30,401,51,159,33,22,91,72,57,47,24,27,72,12],"type":"bar"},{"x":["conditions","neighborhood","optimization","application","intelligence","parameter","directions ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4607,), (4607, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8141666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>kernel</span> <span style=''>for</span> <span style=''>time</span> <span style=''>series</span> <span style=''>based</span> <span style=''>on</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.4736842105263158);'>alignments</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style=''>new</span> <span style=''>family</span> <span style=''>of</span> <span style=''>kernels</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>times</span> <span style=''>series</span> <span style=''>notably</span> <span style=''>speech</span> <span style=''>data</span> <span style=''>within</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>kernel</span> <span style=''>methods</span> <span style=''>which</span> <span style=''>includes</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machine</span> <span style=''>These</span> <span style=''>kernels</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>elaborate</span> <span style=''>on</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>Dynamic</span> <span style=''>Time</span> <span style=''>Warping</span> <span style=''>(DTW)</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.4747474747474748);'>considering</span> <span style=''>the</span> <span style=''>same</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4117647058823529);'>elementary</span> <span style='background-color:rgba(0, 255, 0, 0.4186046511627907);'>operations</span> <span style=''>namely</span> <span style=''>substitutions</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>repetitions</span> <span style=''>of</span> <span style=''>tokens</span> <span style=''>to</span> <span style=''>map</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>onto</span> <span style=''>another</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Associating</span> <span style=''>to</span> <span style=''>each</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.4186046511627907);'>operations</span> <span style=''>a</span> <span style=''>given</span> <span style=''>score</span> <span style=''>DTW</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>use</span> <span style=''>dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.4201183431952663);'>programming</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>an</span> <span style=''>optimal</span> <span style=''>sequence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4186046511627907);'>operations</span> <span style=''>with</span> <span style=''>high</span> <span style=''>overall</span> <span style=''>score</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>instead</span> <span style=''>the</span> <span style=''>score</span> <span style=''>spanned</span> <span style=''>by</span> <span style=''>all</span> <span style=''>possible</span> <span style='background-color:rgba(0, 255, 0, 0.4736842105263158);'>alignments</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>fair</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Predictive</span> <span style=''>modeling</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasingly</span> <span style=''>being</span> <span style=''>employed</span> <span style=''>to</span> <span style=''>assist</span> <span style=''>human</span> <span style=''>decision</span> <span style=''>makers</span> <span style=''>One</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>purported</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>replacing</span> <span style=''>human</span> <span style=''>judgment</span> <span style=''>with</span> <span style=''>computer</span> <span style=''>models</span> <span style=''>in</span> <span style=''>high</span> <span style=''>stakes</span> <span style=''>settings</span> <span style=''>such</span> <span style=''>as</span> <span style=''>sentencing</span> <span style=''>hiring</span> <span style=''>policing</span> <span style=''>college</span> <span style=''>admissions</span> <span style=''>and</span> <span style=''>parole</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decisions</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perceived</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neutrality</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computers</span> <span style=''>It</span> <span style=''>is</span> <span style=''>argued</span> <span style=''>that</span> <span style=''>because</span> <span style=''>computer</span> <span style=''>models</span> <span style=''>do</span> <span style=''>not</span> <span style=''>hold</span> <span style=''>personal</span> <span style=''>prejudice</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>they</span> <span style=''>produce</span> <span style=''>will</span> <span style=''>be</span> <span style=''>equally</span> <span style=''>free</span> <span style=''>from</span> <span style=''>prejudice</span> <span style=''>There</span> <span style=''>is</span> <span style=''>growing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>employing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>does</span> <span style=''>not</span> <span style=''>remove</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>for</span> <span style=''>bias</span> <span style=''>and</span> <span style=''>can</span> <span style=''>even</span> <span style=''>amplify</span> <span style=''>it</span> <span style=''>since</span> <span style=''>training</span> <span style=''>data</span> <span style=''>were</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inevitably</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>a</span> <span style=''>process</span> <span style=''>that</span> <span style=''>is</span> <span style=''>itself</span> <span style=''>biased</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definition</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Distributed</span> <span style=''>Strongly</span> <span style=''>Convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>A</span> <span style=''>lot</span> <span style=''>of</span> <span style=''>effort</span> <span style=''>has</span> <span style=''>been</span> <span style=''>invested</span> <span style=''>into</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterizing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.34201954397394146);'>convergence</span> <span style=''>rates</span> <span style=''>of</span> <span style=''>gradient</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>Recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>and</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>interest</span> <span style=''>has</span> <span style=''>shifted</span> <span style=''>towards</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>strongly</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>Each</span> <span style=''>node</span> <span style=''>in</span> <span style=''>a</span> <span style=''>network</span> <span style=''>of</span> <span style=''>n</span> <span style='background-color:rgba(0, 255, 0, 0.5200000000000001);'>computers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>converges</span> <span style=''>to</span> <span style=''>the</span> <span style=''>optimum</span> <span style=''>of</span> <span style=''>a</span> <span style=''>strongly</span> <span style=''>convex</span> <span style=''>L</span> <span style=''>Lipchitz</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>separable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>at</span> <span style=''>a</span> <span style=''>rate</span> <span style=''>O(log</span> <span style=''>(sqrt(n)</span> <span style=''>T)</span> <span style=''>T)</span> <span style=''>where</span> <span style=''>T</span> <span style=''>is</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterations</span> <span style=''>This</span> <span style=''>rate</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>in</span> <span style=''>the</span> <span style=''>online</span> <span style=''>setting</span> <span style=''>where</span> <span style=''>the</span> <span style=''>data</span> <span style=''>is</span> <span style=''>revealed</span> <span style=''>one</span> <span style=''>at</span> <span style=''>a</span> <span style=''>time</span> <span style=''>to</span> <span style=''>the</span> <span style=''>nodes</span> <span style=''>and</span> <span style=''>in</span> <span style=''>the</span> <span style=''>batch</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Turing</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>metric</span> <span style=''>free</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferring</span> <span style=''>behavior</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>to</span> <span style=''>swarms</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>Turing</span> <span style=''>Learning</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>system</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferring</span> <span style=''>the</span> <span style=''>behavior</span> <span style=''>of</span> <span style=''>natural</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>artificial</span> <span style=''>systems</span> <span style=''>Turing</span> <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizes</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>populations</span> <span style=''>of</span> <span style=''>computer</span> <span style=''>programs</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representing</span> <span style=''>models</span> <span style=''>of</span> <span style=''>the</span> <span style=''>behavior</span> <span style=''>of</span> <span style=''>the</span> <span style=''>system</span> <span style=''>under</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigation</span> <span style=''>and</span> <span style=''>the</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observing</span> <span style=''>the</span> <span style=''>behavior</span> <span style=''>of</span> <span style=''>the</span> <span style=''>system</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>behaviors</span> <span style=''>produced</span> <span style=''>by</span> <span style=''>the</span> <span style=''>models</span> <span style=''>two</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>data</span> <span style=''>samples</span> <span style=''>are</span> <span style=''>obtained</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>are</span> <span style=''>rewarded</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminating</span> <span style=''>between</span> <span style=''>these</span> <span style=''>two</span> <span style=''>sets</span> <span style=''>that</span> <span style=''>is</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correctly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>categorizing</span> <span style=''>data</span> <span style=''>samples</span> <span style=''>as</span> <span style=''>either</span> <span style=''>genuine</span> <span style=''>or</span> <span style=''>counterfeit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conversely</span> <span style=''>the</span> <span style=''>models</span> <span style=''>are</span> <span style=''>rewarded</span> <span style=''>for</span> <span style=''>tricking</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>into</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12255772646536411)
# 	processing (0.10195381882770871)
# 	information (0.23836589698046182)
# 	experimental (0.14103019538188277)
# 	architecture (0.0905861456483126)
# 	segmentation (0.07424511545293074)
# 	detection (0.12966252220248667)
# 	different (0.26962699822380104)
# 	convolutional (0.12397868561278863)
# 	recognition (0.1424511545293073)
#
# Some Statistics words are:
# 	stochastic (0.1304785894206549)
# 	theoretical (0.14458438287153652)
# 	variables (0.14055415617128464)
# 	estimation (0.17380352644836272)
# 	inference (0.1894206549118388)
# 	distribution (0.18639798488664988)
# 	statistical (0.16574307304785893)
# 	dimensional (0.19093198992443325)
# 	algorithm (0.3924433249370277)
# 	regression (0.18438287153652394)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="46531416-b01d-445a-8634-d05aecbd5154" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46531416-b01d-445a-8634-d05aecbd5154")) {                    Plotly.newPlot(                        "46531416-b01d-445a-8634-d05aecbd5154",                        [{"x":["conditions","neighborhood","optimization","application","intelligence","parameter","directions","successful","condition","artificial","understanding","characterization","regularity","witnessed","theoretical","functions","quadratic","specifically","properties","landscape","nonlinear","desirable","dominance","establish","understood","minimizers","challenging","improvements","analyzing","prediction","segmentation","boundaries","recognition","recurrent","algorithm","hypothesize","unsupervised","environment","principle","correlation","explanation","ambiguous","multivariate","automating","characterized","suggested","effortlessly","representations","translated","supervised","information","dependence","including","successes","supervision","redundancy","theoretic","tradeoffs","programming","experiments","coordinate","conjunctive","disjunctive","algorithms","principled","minimization","contribution","objective","classification","characterize","alternating","relaxation","objectives","procedures","framework","interpretable","efficient","interpretability","inference","techniques","discussed","processing","containing","characteristic","recognize","dimensional","initialized","identification","determine","uncertainty","vagueness","alternatively","indicator","ambiguity","probability","frameworks","engineering","conceptual","adaptable","introduced","discusses","potential","distinguished","possibility","knowledge","observable","environments","acquisition","exploration","sensorimotor","extracting","emphasize","observation","integrates","partially","representation","autonomously","regularities","propagation","fortunately","experimental","bipartite","granularity","computationally","demonstrates","resulting","construct","exploring","facilitate","convolutional","collected","optimized","structure","applications","difference","restaurants","benchmark","restaurant","relationships","available","naturally","constrained","resolution","frequency","traditional","synthesis","conflicts","integrate","reviewing","assignment","separately","traditionally","preferences","assigning","formulation","predicting","integrated","management","preference","distribution","submissions","constraints","recommender","conference","assignments","reviewers","expertise","affinities","evaluated","demonstrate","practical","notwithstanding","approximation","underlying","estimating","presented","potentially","solutions","scenarios","variational","procedure","marginalization","empirical","corruptions","generative","relaxations","correctly","approaches","applicable","attention","guarantee","frequently","component","generally","minimizing","completely","intractable","consequently","methodology","surrogate","principal","alternative","implementations","consolidation","additionally","additional","complexity","computation","different","quantization","comparative","detection","comparing","reduction","quantized","embedding","transformations","associated","repetitive","applicability","probabilistic","configurations","pedestrians","neighborhoods","conducting","stochastically","interdependency","stationarity","temporally","according","distributed","sequences","spatially","spatiotemporal","understand","unfortunately","reexamine","uninformed","searching","difficult","performance","significantly","conclusions","replicate","supporting","systematic","specialized","exploiting","performing","published","motivates","replicated","annotated","exacerbated","estimat ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	compressibility
# 	encompassing
# 	advocated
# 	detectability
# 	datastreams
# 	resiliency
# 	confounder
# 	confounders
# 	convincingly
# 	wirtinger
# 	spectroradiometer
# 	reflectivity
# 	covariates
# 	tibshirani
# 	photovoltaic
# 	catalogue
# 	purchasing
# 	cytometry
# 	affirmative
# 	diameters
# Some words which never appear in Statistics papers:
# 	vagueness
# 	sensorimotor
# 	autonomously
# 	fortunately
# 	submissions
# 	reviewers
# 	repetitive
# 	occlusions
# 	monocular
# 	manipulation
# 	functionalities
# 	bioinspired
# 	plasticity
# 	collision
# 	historically
# 	symbiotic
# 	breakpoints
# 	polyhedron
# 	ontologies
# 	governments

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.052782611350246e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7666666666666667
